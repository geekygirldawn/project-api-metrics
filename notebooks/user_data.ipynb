# %% [markdown]
# This notebook is designed to get information about a GitHub user from the GraphQL API.
#
# Assumptions / requirements:
# - `gh_key`: assumes you have a file in this directory called `gh_key` with your API token. You can change this and get your token from elsewhere in the cell below.
# - `start_date` and `end_date`: these are specified in the cell below and cannot be more than 1 year apart. You can run an additional query if you need more than 1 year of data.
# - `user_login`: a variable that specifies the user that you want to gather data about in the cell below.

# %%
# Copyright 2022 VMware, Inc.
# SPDX-License-Identifier: BSD-2-Clause

import requests
import json
import pandas as pd
from pandas import json_normalize
from datetime import datetime

with open('gh_key', 'r') as kf:
    api_token = kf.readline().rstrip() # remove newline & trailing whitespace
url = 'https://api.github.com/graphql'
headers = {'Authorization': 'token %s' % api_token}

start_date = datetime(2021, 1, 1).isoformat() #isoformat required for json serialization
end_date = datetime(2021, 12, 31).isoformat()
user_login = 'jberkus'
variables = {"user_login": user_login, "start_date": start_date, "end_date": end_date}

# %%
def run_query(url, headers, variables, make_query):
    '''Basic function to run any of the queries below'''
    import requests
    import json
    
    query = make_query()
    r = requests.post(url=url, json={'query': query, 'variables': variables}, headers=headers)
    json_data = json.loads(r.text)
    
    return json_data

# %% [markdown]
# # Basic Info
#
# Get basic information about a user and the number of various types of contributions they have made during the specified time.

# %%
def basic_info_query():
    return """query basic_info_user_query($user_login: String!, $start_date: DateTime!, $end_date: DateTime!){
             user(login: $user_login) {
                name
                bio
                location
                company
                twitterUsername
                websiteUrl
                contributionsCollection(from: $start_date, to: $end_date){
                    totalCommitContributions
                    totalIssueContributions
                    totalPullRequestContributions
                    totalPullRequestReviewContributions
                    totalRepositoriesWithContributedCommits
                    totalRepositoriesWithContributedIssues
                    totalRepositoriesWithContributedPullRequestReviews
                    totalRepositoriesWithContributedPullRequests
                }
            }
            }"""

basic_info_json_data = run_query(url, headers, variables, basic_info_query)
basic_info_json_data['data']['user']
# Out:
# {'name': 'Josh Berkus',
#  'bio': 'Twitter: @fuzzychef\r\nKubernetes Slack: jberkus\r\nIRC.freenode.net: jberkus',
#  'location': 'Portland, OR',
#  'company': 'Red Hat',
#  'twitterUsername': None,
#  'websiteUrl': 'http://jberkus.github.io',
#  'contributionsCollection': {'totalCommitContributions': 280,
#   'totalIssueContributions': 65,
#   'totalPullRequestContributions': 96,
#   'totalPullRequestReviewContributions': 28,
#   'totalRepositoriesWithContributedCommits': 31,
#   'totalRepositoriesWithContributedIssues': 23,
#   'totalRepositoriesWithContributedPullRequestReviews': 14,
#   'totalRepositoriesWithContributedPullRequests': 24}}

# %% [markdown]
# # Pull Requests
#
# Get a list of a user's pull requests during the specified time with details about the PRs.

# %%
def pr_info_query(after_cursor = None):
    return """query pr_info_query($user_login: String!, $start_date: DateTime!, $end_date: DateTime!){
             user(login: $user_login) {
                contributionsCollection(from: $start_date, to: $end_date){
                    pullRequestContributions(first: 100 after: AFTER){
                        pageInfo {
                           hasNextPage
                           endCursor
                        }
                        nodes{
                            pullRequest{
                                repository{
                                    nameWithOwner
                                }
                                createdAt
                                updatedAt
                                changedFiles
                                additions
                                deletions
                                state
                            }
                        }
                    }
                }
            }
            }""".replace(
        "AFTER", '"{}"'.format(after_cursor) if after_cursor else "null"
    )

has_next_page = True
after_cursor = None

pr_info_json_data = {}
    
while has_next_page:
    temp_json_data = run_query(url, headers, variables, lambda: pr_info_query(after_cursor))
    
    if not after_cursor:
        pr_info_json_data = temp_json_data["data"]["user"]["contributionsCollection"]["pullRequestContributions"]["nodes"]
    else:
        for pr in temp_json_data["data"]["user"]["contributionsCollection"]["pullRequestContributions"]["nodes"]:
            if pr:
                pr_info_json_data.append(pr)
       
    has_next_page = temp_json_data["data"]["user"]["contributionsCollection"]["pullRequestContributions"]["pageInfo"]["hasNextPage"]
    after_cursor = temp_json_data["data"]["user"]["contributionsCollection"]["pullRequestContributions"]["pageInfo"]["endCursor"]

if pr_info_json_data:
    pr_info_json_data = list(filter(None, pr_info_json_data))
    pr_df = pd.DataFrame(pr_info_json_data)
    pr_df = pr_df.join(json_normalize(pr_df["pullRequest"].tolist()))
    pr_df = pr_df.drop("pullRequest", axis=1)
else:
    pr_df = "No Pull Requests"

pr_df
# Out:
#                createdAt             updatedAt  changedFiles  additions  \
# 0   2021-12-17T21:02:36Z  2022-01-05T13:52:35Z             1          3
# 1   2021-12-17T18:25:21Z  2021-12-17T18:29:53Z             3         59
# 2   2021-12-14T01:58:11Z  2021-12-14T03:00:04Z             1          5
# 3   2021-12-14T01:54:02Z  2021-12-14T16:30:48Z             1          0
# 4   2021-12-10T01:12:54Z  2021-12-12T22:15:58Z             1       4168
# ..                   ...                   ...           ...        ...
# 91  2021-03-19T20:27:23Z  2021-04-26T13:57:28Z             2         11
# 92  2021-03-17T23:38:44Z  2021-03-18T09:41:28Z             1          0
# 93  2021-02-24T00:20:46Z  2021-02-25T14:29:30Z             1          6
# 94  2021-01-15T23:09:12Z  2021-03-18T17:28:11Z             2        174
# 95  2021-01-06T00:48:50Z  2021-01-06T00:49:33Z             1         17
#
#     deletions   state              repository.nameWithOwner
# 0           2  MERGED                  kubernetes/community
# 1           0    OPEN  cncf/cloud-native-community-cookbook
# 2           4  MERGED           kubernetes/contributor-site
# 3          10  MERGED           kubernetes/contributor-site
# 4           0  MERGED                  kubernetes/community
# ..        ...     ...                                   ...
# 91          2  CLOSED                     containers/podman
# 92          6  MERGED                kubernetes/sig-release
# 93          3  MERGED                  kubernetes/community
# 94          0  MERGED                 cncf/project-template
# 95         27  MERGED          containers/ContainerPlumbing
#
# [96 rows x 7 columns]

# %% [markdown]
# # Respositories Contributed to
#
# The list of repositories this user has contributed to.
#
# Note: The repositoriesContributedTo object does not take a start / end time and the API documentation states that this is "A list of repositories that the user recently contributed to.", but doesn't actually define "recently". Based on how they define this elsewhere and the data I'm seeing, I suspect that this is the past 1 year of data.

# %%
def repo_info_query(after_cursor = None):
    return """query repo_info_query($user_login: String!){
             user(login: $user_login) {
                repositoriesContributedTo(first: 100 includeUserRepositories: true after: AFTER){
                    pageInfo {
                        hasNextPage
                        endCursor
                    }
                    totalCount
                    nodes{
                        nameWithOwner
                    }
                }
            }    
            }""".replace(
        "AFTER", '"{}"'.format(after_cursor) if after_cursor else "null"
    )

has_next_page = True
after_cursor = None

repo_info_json_data = {}
    
while has_next_page:
    temp_json_data = run_query(url, headers, variables, lambda: repo_info_query(after_cursor))

    if not after_cursor:
        repo_info_json_data = temp_json_data["data"]["user"]["repositoriesContributedTo"]["nodes"]
    else:
        for pr in temp_json_data["data"]["user"]["repositoriesContributedTo"]["nodes"]:
            if pr:
                repo_info_json_data.append(pr)

    has_next_page = temp_json_data["data"]["user"]["repositoriesContributedTo"]["pageInfo"]["hasNextPage"]
    after_cursor = temp_json_data["data"]["user"]["repositoriesContributedTo"]["pageInfo"]["endCursor"]
  
print(len(repo_info_json_data))
repo_info_json_data
# Out:
# 55
# [{'nameWithOwner': 'projectatomic/atomic-site'},
#  {'nameWithOwner': 'apache/superset'},
#  {'nameWithOwner': 'jberkus/jberkus.github.io'},
#  {'nameWithOwner': 'yo7/count-word'},
#  {'nameWithOwner': 'cncf/toc'},
#  {'nameWithOwner': 'kubernetes/website'},
#  {'nameWithOwner': 'kubernetes/test-infra'},
#  {'nameWithOwner': 'kubernetes/enhancements'},
#  {'nameWithOwner': 'kubernetes/community'},
#  {'nameWithOwner': 'cncf/foundation'},
#  {'nameWithOwner': 'kubernetes/k8s.io'},
#  {'nameWithOwner': 'kubevirt/community'},
#  {'nameWithOwner': 'kubevirt/kubevirt'},
#  {'nameWithOwner': 'chaoss/augur'},
#  {'nameWithOwner': 'cncf/mentoring'},
#  {'nameWithOwner': 'kubevirt/kubevirt.github.io'},
#  {'nameWithOwner': 'kubernetes/sig-release'},
#  {'nameWithOwner': 'cncf/devstats'},
#  {'nameWithOwner': 'istio/community'},
#  {'nameWithOwner': 'kubernetes/steering'},
#  {'nameWithOwner': 'containers/podman'},
#  {'nameWithOwner': 'kubernetes-sigs/lwkd'},
#  {'nameWithOwner': 'jberkus/annotated.conf'},
#  {'nameWithOwner': 'kubernetes/org'},
#  {'nameWithOwner': 'knative/docs'},
#  {'nameWithOwner': 'kubernetes/contributor-site'},
#  {'nameWithOwner': 'etcd-io/website'},
#  {'nameWithOwner': 'knative/community'},
#  {'nameWithOwner': 'cncf/tag-contributor-strategy'},
#  {'nameWithOwner': 'open-cluster-management-io/community'},
#  {'nameWithOwner': 'CommunityCentral/communitycentral.github.io'},
#  {'nameWithOwner': 'cncf/project-template'},
#  {'nameWithOwner': 'konveyor/community'},
#  {'nameWithOwner': 'containers/ContainerPlumbing'},
#  {'nameWithOwner': 'elekto-io/elekto'},
#  {'nameWithOwner': 'elekto-io/elekto.meta.test'},
#  {'nameWithOwner': 'elekto-io/docs'},
#  {'nameWithOwner': 'QiushiWu/qiushiwu.github.io'},
#  {'nameWithOwner': 'jberkus/podman'},
#  {'nameWithOwner': 'carolynvs/contributor-strategy-talks'},
#  {'nameWithOwner': 'jberkus/community-3'},
#  {'nameWithOwner': 'cncf/cloud-native-community-cookbook'},
#  {'nameWithOwner': 'jberkus/community-4'},
#  {'nameWithOwner': 'jberkus/community-5'},
#  {'nameWithOwner': 'jberkus/augur'},
#  {'nameWithOwner': 'github/MVG'},
#  {'nameWithOwner': 'Diamond-Bluff/Diamond-Bluff'},
#  {'nameWithOwner': 'jberkus/superset'},
#  {'nameWithOwner': 'jberkus/kubevirt'},
#  {'nameWithOwner': 'okd-virtualization/okd-virtualization.github.io'},
#  {'nameWithOwner': 'jberkus/contributor-site'},
#  {'nameWithOwner': 'jberkus/okd-virtualization.github.io'},
#  {'nameWithOwner': 'jberkus/opengovernance.dev'},
#  {'nameWithOwner': 'kubernetes-sigs/contributor-katacoda'},
#  {'nameWithOwner': 'jberkus/cloud-native-community-cookbook'}]

# %% [markdown]
# # Repositories with Total Count of Commits
#
# This is another way of getting at the repository data, but this time with the number of commits.
#
# Note: You can only get this data for a maximum of 100 repos.
#
# Note: The number of repos is different from above, but looking at the data, I think maybe that commits to forks are excluded.

# %%
def repo_commits_info_query(after_cursor = None):
    return """query pr_info_query($user_login: String!, $start_date: DateTime!, $end_date: DateTime!){
             user(login: $user_login) {
                contributionsCollection(from: $start_date, to: $end_date){
                    commitContributionsByRepository(maxRepositories: 100){
                        repository{
                            nameWithOwner
                        }
                        contributions{
                            totalCount
                        }
                    }
                    }
                }
                }""".replace(
        "AFTER", '"{}"'.format(after_cursor) if after_cursor else "null"
    )

repo_commits_info_json_data = run_query(url, headers, variables, lambda: repo_commits_info_query(after_cursor))

repo_commits_info_json_data
                    
if repo_commits_info_json_data:
    repo_commits_df = pd.DataFrame(repo_commits_info_json_data['data']['user']['contributionsCollection']['commitContributionsByRepository'])
    repo_commits_df['repo'] = repo_commits_df.repository.str['nameWithOwner']
    repo_commits_df['commits'] = repo_commits_df.contributions.str['totalCount']
    repo_commits_df = repo_commits_df.drop("repository", axis=1)
    repo_commits_df = repo_commits_df.drop("contributions", axis=1)
else:
    repo_commits_df = "No Commits"
    
repo_commits_df
# Out:
#                                                repo  commits
# 0                              kubernetes-sigs/lwkd       71
# 1                                  elekto-io/elekto       33
# 2                      containers/ContainerPlumbing       28
# 3                                    elekto-io/docs       24
# 4                              kubernetes/community       23
# 5                     cncf/tag-contributor-strategy       22
# 6                                 knative/community       13
# 7                                 kubernetes/k8s.io       11
# 8                        elekto-io/elekto.meta.test       11
# 9              carolynvs/contributor-strategy-talks        7
# 10      CommunityCentral/communitycentral.github.io        6
# 11                      kubernetes/contributor-site        3
# 12                            cncf/project-template        3
# 13                                         cncf/toc        2
# 14                                  etcd-io/website        2
# 15                        jberkus/jberkus.github.io        2
# 16                               kubevirt/community        2
# 17                      kubevirt/kubevirt.github.io        2
# 18                               konveyor/community        2
# 19                                     knative/docs        2
# 20                               kubernetes/website        1
# 21  okd-virtualization/okd-virtualization.github.io        1
# 22                              kubernetes/steering        1
# 23                                kubevirt/kubevirt        1
# 24                                  apache/superset        1
# 25                                     chaoss/augur        1
# 26                          kubernetes/enhancements        1
# 27                                containers/podman        1
# 28                           kubernetes/sig-release        1
# 29                   elekto-io/elekto.meta.template        1
# 30                       elekto-io/elekto.github.io        1

# %% [markdown]
# # Older Experiment getting the data above as one big query
#
# Note: Data gathered from this query is most likely incomplete. Since this was a quick experiment to better understand the User object, I simply gathered the first 100 of several objects with no pagination, and I hardcoded in the user_login and start / end dates.

# %%
def make_query():
    return """query user_query($user_login: String!, $start_date: DateTime!, $end_date: DateTime!){
             user(login: $user_login) {
                name
                contributionsCollection(from: $start_date, to: $end_date){
                    totalCommitContributions
                    totalIssueContributions
                    totalPullRequestContributions
                    totalPullRequestReviewContributions
                    totalRepositoriesWithContributedCommits
                    totalRepositoriesWithContributedIssues
                    totalRepositoriesWithContributedPullRequestReviews
                    totalRepositoriesWithContributedPullRequests
                    pullRequestContributions(first: 100){
                        nodes{
                            pullRequest{
                                repository{
                                    nameWithOwner
                                }
                                createdAt
                                updatedAt
                                changedFiles
                                additions
                                deletions
                                state
                            }
                        }
                    }
                    commitContributionsByRepository{
                        repository{
                            nameWithOwner
                        }
                        contributions(first:100){
                            totalCount
                            nodes{
                                occurredAt
                                commitCount
                            }
                        }
                    }
                }
             }
             }"""

# %%
def get_user_data(api_token):
    import requests
    import json
    import pandas as pd
    from datetime import datetime

    url = 'https://api.github.com/graphql'
    headers = {'Authorization': 'token %s' % api_token}
    
    start_date = datetime(2021, 1, 1).isoformat() #isoformat required for json serialization
    end_date = datetime(2021, 12, 31).isoformat()
    
    query = make_query()
    
    user_login = "jberkus"

    variables = {"user_login": user_login, "start_date": start_date, "end_date": end_date}
    r = requests.post(url=url, json={'query': query, 'variables': variables}, headers=headers)
    json_data = json.loads(r.text)
    
    return json_data
    
json_data = get_user_data(api_token)

# %%
json_data
# Out:
# {'data': {'user': {'name': 'Josh Berkus',
#    'contributionsCollection': {'totalCommitContributions': 280,
#     'totalIssueContributions': 65,
#     'totalPullRequestContributions': 96,
#     'totalPullRequestReviewContributions': 28,
#     'totalRepositoriesWithContributedCommits': 31,
#     'totalRepositoriesWithContributedIssues': 23,
#     'totalRepositoriesWithContributedPullRequestReviews': 14,
#     'totalRepositoriesWithContributedPullRequests': 24,
#     'pullRequestContributions': {'nodes': [{'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/community'},
#         'createdAt': '2021-12-17T21:02:36Z',
#         'updatedAt': '2022-01-05T13:52:35Z',
#         'changedFiles': 1,
#         'additions': 3,
#         'deletions': 2,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'cncf/cloud-native-community-cookbook'},
#         'createdAt': '2021-12-17T18:25:21Z',
#         'updatedAt': '2021-12-17T18:29:53Z',
#         'changedFiles': 3,
#         'additions': 59,
#         'deletions': 0,
#         'state': 'OPEN'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/contributor-site'},
#         'createdAt': '2021-12-14T01:58:11Z',
#         'updatedAt': '2021-12-14T03:00:04Z',
#         'changedFiles': 1,
#         'additions': 5,
#         'deletions': 4,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/contributor-site'},
#         'createdAt': '2021-12-14T01:54:02Z',
#         'updatedAt': '2021-12-14T16:30:48Z',
#         'changedFiles': 1,
#         'additions': 0,
#         'deletions': 10,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/community'},
#         'createdAt': '2021-12-10T01:12:54Z',
#         'updatedAt': '2021-12-12T22:15:58Z',
#         'changedFiles': 1,
#         'additions': 4168,
#         'deletions': 0,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'cncf/tag-contributor-strategy'},
#         'createdAt': '2021-12-09T23:18:46Z',
#         'updatedAt': '2021-12-10T11:12:46Z',
#         'changedFiles': 2,
#         'additions': 12,
#         'deletions': 0,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'cncf/toc'},
#         'createdAt': '2021-12-07T21:33:23Z',
#         'updatedAt': '2021-12-07T23:02:44Z',
#         'changedFiles': 1,
#         'additions': 1,
#         'deletions': 1,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/contributor-site'},
#         'createdAt': '2021-12-06T23:43:09Z',
#         'updatedAt': '2021-12-07T00:06:02Z',
#         'changedFiles': 1,
#         'additions': 9,
#         'deletions': 1,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/community'},
#         'createdAt': '2021-12-02T23:29:05Z',
#         'updatedAt': '2021-12-10T07:49:10Z',
#         'changedFiles': 3,
#         'additions': 272,
#         'deletions': 7,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'knative/community'},
#         'createdAt': '2021-12-02T16:57:49Z',
#         'updatedAt': '2021-12-02T17:01:46Z',
#         'changedFiles': 2,
#         'additions': 65,
#         'deletions': 0,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'knative/community'},
#         'createdAt': '2021-11-29T19:53:02Z',
#         'updatedAt': '2021-11-29T19:55:05Z',
#         'changedFiles': 1,
#         'additions': 3,
#         'deletions': 3,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'knative/community'},
#         'createdAt': '2021-11-16T17:18:28Z',
#         'updatedAt': '2021-11-16T17:21:00Z',
#         'changedFiles': 1,
#         'additions': 1,
#         'deletions': 1,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/website'},
#         'createdAt': '2021-11-09T18:06:32Z',
#         'updatedAt': '2021-11-09T18:53:48Z',
#         'changedFiles': 1,
#         'additions': 2,
#         'deletions': 0,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'knative/community'},
#         'createdAt': '2021-11-08T23:07:53Z',
#         'updatedAt': '2021-11-08T23:13:43Z',
#         'changedFiles': 3,
#         'additions': 9,
#         'deletions': 5,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/community'},
#         'createdAt': '2021-11-08T21:23:42Z',
#         'updatedAt': '2021-11-09T00:36:49Z',
#         'changedFiles': 1,
#         'additions': 1,
#         'deletions': 0,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/community'},
#         'createdAt': '2021-11-08T21:08:14Z',
#         'updatedAt': '2021-11-08T21:35:22Z',
#         'changedFiles': 1,
#         'additions': 0,
#         'deletions': 0,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/community'},
#         'createdAt': '2021-11-08T17:46:21Z',
#         'updatedAt': '2021-11-08T20:27:20Z',
#         'changedFiles': 1,
#         'additions': 26,
#         'deletions': 0,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/community'},
#         'createdAt': '2021-11-05T19:32:00Z',
#         'updatedAt': '2021-11-05T19:38:40Z',
#         'changedFiles': 1,
#         'additions': 2,
#         'deletions': 2,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'knative/community'},
#         'createdAt': '2021-11-04T18:09:12Z',
#         'updatedAt': '2021-11-04T18:18:01Z',
#         'changedFiles': 1,
#         'additions': 2,
#         'deletions': 2,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'okd-virtualization/okd-virtualization.github.io'},
#         'createdAt': '2021-10-25T20:22:33Z',
#         'updatedAt': '2021-11-23T08:29:08Z',
#         'changedFiles': 1,
#         'additions': 1,
#         'deletions': 1,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'elekto-io/docs'},
#         'createdAt': '2021-10-21T23:14:32Z',
#         'updatedAt': '2022-01-07T01:22:37Z',
#         'changedFiles': 8,
#         'additions': 503,
#         'deletions': 84,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/k8s.io'},
#         'createdAt': '2021-10-20T20:04:47Z',
#         'updatedAt': '2021-10-21T03:32:09Z',
#         'changedFiles': 1,
#         'additions': 1,
#         'deletions': 1,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/k8s.io'},
#         'createdAt': '2021-10-20T18:20:14Z',
#         'updatedAt': '2021-10-20T18:22:40Z',
#         'changedFiles': 1,
#         'additions': 1,
#         'deletions': 1,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/k8s.io'},
#         'createdAt': '2021-10-20T16:44:20Z',
#         'updatedAt': '2021-10-20T18:06:39Z',
#         'changedFiles': 1,
#         'additions': 1,
#         'deletions': 1,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'elekto-io/docs'},
#         'createdAt': '2021-10-20T00:01:24Z',
#         'updatedAt': '2021-10-20T15:34:48Z',
#         'changedFiles': 3,
#         'additions': 4,
#         'deletions': 4,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/k8s.io'},
#         'createdAt': '2021-10-19T18:09:50Z',
#         'updatedAt': '2021-10-19T19:28:16Z',
#         'changedFiles': 1,
#         'additions': 1,
#         'deletions': 1,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'elekto-io/elekto'},
#         'createdAt': '2021-10-19T01:00:22Z',
#         'updatedAt': '2021-10-19T16:39:30Z',
#         'changedFiles': 3,
#         'additions': 13,
#         'deletions': 8,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'knative/community'},
#         'createdAt': '2021-10-18T19:55:18Z',
#         'updatedAt': '2021-10-20T17:06:53Z',
#         'changedFiles': 6,
#         'additions': 175,
#         'deletions': 11,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/community'},
#         'createdAt': '2021-10-16T22:09:36Z',
#         'updatedAt': '2021-10-16T22:25:49Z',
#         'changedFiles': 1,
#         'additions': 1,
#         'deletions': 1,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/community'},
#         'createdAt': '2021-10-15T21:26:05Z',
#         'updatedAt': '2021-10-15T21:27:16Z',
#         'changedFiles': 1,
#         'additions': 1,
#         'deletions': 1,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/community'},
#         'createdAt': '2021-10-09T00:12:52Z',
#         'updatedAt': '2021-10-09T18:36:41Z',
#         'changedFiles': 2,
#         'additions': 5,
#         'deletions': 1,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/community'},
#         'createdAt': '2021-10-08T23:51:16Z',
#         'updatedAt': '2021-10-08T23:54:36Z',
#         'changedFiles': 1,
#         'additions': 3,
#         'deletions': 3,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/community'},
#         'createdAt': '2021-10-08T23:03:00Z',
#         'updatedAt': '2021-10-08T23:17:38Z',
#         'changedFiles': 3,
#         'additions': 22,
#         'deletions': 4,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/k8s.io'},
#         'createdAt': '2021-10-07T18:33:40Z',
#         'updatedAt': '2021-10-07T18:37:35Z',
#         'changedFiles': 1,
#         'additions': 1,
#         'deletions': 1,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'elekto-io/elekto'},
#         'createdAt': '2021-10-06T23:58:34Z',
#         'updatedAt': '2021-10-06T23:58:44Z',
#         'changedFiles': 3,
#         'additions': 20,
#         'deletions': 1,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/community'},
#         'createdAt': '2021-10-06T00:12:58Z',
#         'updatedAt': '2021-10-07T22:47:33Z',
#         'changedFiles': 1,
#         'additions': 29,
#         'deletions': 0,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/community'},
#         'createdAt': '2021-10-05T21:36:11Z',
#         'updatedAt': '2021-10-05T21:38:59Z',
#         'changedFiles': 1,
#         'additions': 1,
#         'deletions': 1,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/community'},
#         'createdAt': '2021-10-05T20:29:26Z',
#         'updatedAt': '2021-10-05T20:50:58Z',
#         'changedFiles': 2,
#         'additions': 1,
#         'deletions': 1,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/community'},
#         'createdAt': '2021-10-05T19:24:21Z',
#         'updatedAt': '2021-10-05T19:26:58Z',
#         'changedFiles': 1,
#         'additions': 1,
#         'deletions': 1,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/community'},
#         'createdAt': '2021-10-05T19:00:38Z',
#         'updatedAt': '2021-10-05T19:18:58Z',
#         'changedFiles': 2,
#         'additions': 2,
#         'deletions': 2,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'elekto-io/docs'},
#         'createdAt': '2021-10-04T20:43:59Z',
#         'updatedAt': '2021-10-04T20:47:51Z',
#         'changedFiles': 12,
#         'additions': 119,
#         'deletions': 0,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'elekto-io/docs'},
#         'createdAt': '2021-10-04T20:34:25Z',
#         'updatedAt': '2021-10-04T20:42:55Z',
#         'changedFiles': 12,
#         'additions': 119,
#         'deletions': 0,
#         'state': 'CLOSED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'elekto-io/elekto'},
#         'createdAt': '2021-10-01T20:31:15Z',
#         'updatedAt': '2021-10-07T21:29:15Z',
#         'changedFiles': 8,
#         'additions': 165,
#         'deletions': 0,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/community'},
#         'createdAt': '2021-10-01T19:16:26Z',
#         'updatedAt': '2021-10-04T22:12:41Z',
#         'changedFiles': 1,
#         'additions': 22,
#         'deletions': 0,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/community'},
#         'createdAt': '2021-10-01T18:33:18Z',
#         'updatedAt': '2021-10-01T18:40:19Z',
#         'changedFiles': 2,
#         'additions': 12,
#         'deletions': 2,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/community'},
#         'createdAt': '2021-09-30T18:25:59Z',
#         'updatedAt': '2021-10-01T00:19:22Z',
#         'changedFiles': 1,
#         'additions': 1,
#         'deletions': 0,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/steering'},
#         'createdAt': '2021-09-30T01:16:15Z',
#         'updatedAt': '2021-09-30T01:26:08Z',
#         'changedFiles': 1,
#         'additions': 11,
#         'deletions': 12,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/community'},
#         'createdAt': '2021-09-26T18:59:48Z',
#         'updatedAt': '2021-09-27T15:13:37Z',
#         'changedFiles': 3,
#         'additions': 21,
#         'deletions': 20,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/k8s.io'},
#         'createdAt': '2021-09-24T20:13:49Z',
#         'updatedAt': '2021-09-24T20:19:51Z',
#         'changedFiles': 1,
#         'additions': 10,
#         'deletions': 1,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'elekto-io/elekto'},
#         'createdAt': '2021-09-24T19:33:22Z',
#         'updatedAt': '2021-09-24T19:33:30Z',
#         'changedFiles': 1,
#         'additions': 5,
#         'deletions': 0,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/k8s.io'},
#         'createdAt': '2021-09-23T21:46:22Z',
#         'updatedAt': '2021-09-23T21:48:55Z',
#         'changedFiles': 1,
#         'additions': 3,
#         'deletions': 3,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/k8s.io'},
#         'createdAt': '2021-09-23T20:59:59Z',
#         'updatedAt': '2021-09-23T21:10:55Z',
#         'changedFiles': 1,
#         'additions': 1,
#         'deletions': 1,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/k8s.io'},
#         'createdAt': '2021-09-21T23:40:17Z',
#         'updatedAt': '2021-09-23T21:22:01Z',
#         'changedFiles': 6,
#         'additions': 173,
#         'deletions': 0,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/community'},
#         'createdAt': '2021-09-01T19:58:50Z',
#         'updatedAt': '2021-09-17T04:49:00Z',
#         'changedFiles': 7,
#         'additions': 133,
#         'deletions': 83,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'elekto-io/elekto'},
#         'createdAt': '2021-08-30T00:44:28Z',
#         'updatedAt': '2021-09-01T18:51:22Z',
#         'changedFiles': 4,
#         'additions': 27,
#         'deletions': 1,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'elekto-io/elekto'},
#         'createdAt': '2021-08-23T22:07:25Z',
#         'updatedAt': '2021-08-25T00:10:11Z',
#         'changedFiles': 4,
#         'additions': 19,
#         'deletions': 14,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubevirt/kubevirt'},
#         'createdAt': '2021-08-18T00:27:35Z',
#         'updatedAt': '2021-08-19T07:11:08Z',
#         'changedFiles': 2,
#         'additions': 5,
#         'deletions': 9,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubevirt/kubevirt.github.io'},
#         'createdAt': '2021-08-18T00:07:10Z',
#         'updatedAt': '2021-08-18T12:51:02Z',
#         'changedFiles': 1,
#         'additions': 3,
#         'deletions': 3,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes-sigs/lwkd'},
#         'createdAt': '2021-08-17T20:17:09Z',
#         'updatedAt': '2021-08-17T22:28:27Z',
#         'changedFiles': 3,
#         'additions': 11,
#         'deletions': 4,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'apache/superset'},
#         'createdAt': '2021-08-07T00:34:44Z',
#         'updatedAt': '2021-08-07T00:52:30Z',
#         'changedFiles': 1,
#         'additions': 12,
#         'deletions': 0,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'elekto-io/docs'},
#         'createdAt': '2021-08-06T00:06:48Z',
#         'updatedAt': '2021-08-06T16:40:12Z',
#         'changedFiles': 3,
#         'additions': 24,
#         'deletions': 63,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'elekto-io/docs'},
#         'createdAt': '2021-08-05T23:43:54Z',
#         'updatedAt': '2021-08-06T00:05:55Z',
#         'changedFiles': 5,
#         'additions': 25,
#         'deletions': 102,
#         'state': 'CLOSED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/k8s.io'},
#         'createdAt': '2021-08-03T20:33:48Z',
#         'updatedAt': '2021-08-06T17:27:29Z',
#         'changedFiles': 2,
#         'additions': 12,
#         'deletions': 0,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'elekto-io/elekto'},
#         'createdAt': '2021-07-31T00:35:44Z',
#         'updatedAt': '2021-08-01T22:46:39Z',
#         'changedFiles': 5,
#         'additions': 44,
#         'deletions': 2,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes-sigs/lwkd'},
#         'createdAt': '2021-07-31T00:29:58Z',
#         'updatedAt': '2021-08-03T00:00:26Z',
#         'changedFiles': 4,
#         'additions': 7,
#         'deletions': 12,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'konveyor/community'},
#         'createdAt': '2021-07-29T00:28:53Z',
#         'updatedAt': '2021-07-29T01:17:40Z',
#         'changedFiles': 1,
#         'additions': 37,
#         'deletions': 0,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'elekto-io/elekto'},
#         'createdAt': '2021-07-28T23:27:50Z',
#         'updatedAt': '2021-07-30T20:30:53Z',
#         'changedFiles': 3,
#         'additions': 13,
#         'deletions': 2,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'chaoss/augur'},
#         'createdAt': '2021-07-16T23:05:10Z',
#         'updatedAt': '2021-07-19T15:25:27Z',
#         'changedFiles': 1,
#         'additions': 1,
#         'deletions': 0,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'containers/podman'},
#         'createdAt': '2021-07-15T21:26:29Z',
#         'updatedAt': '2021-07-16T16:16:56Z',
#         'changedFiles': 1,
#         'additions': 1,
#         'deletions': 1,
#         'state': 'CLOSED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'open-cluster-management-io/community'},
#         'createdAt': '2021-07-09T00:52:01Z',
#         'updatedAt': '2021-11-23T21:29:04Z',
#         'changedFiles': 2,
#         'additions': 330,
#         'deletions': 0,
#         'state': 'OPEN'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubevirt/community'},
#         'createdAt': '2021-07-08T23:42:25Z',
#         'updatedAt': '2021-09-02T12:35:17Z',
#         'changedFiles': 2,
#         'additions': 120,
#         'deletions': 0,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubevirt/community'},
#         'createdAt': '2021-07-08T23:10:38Z',
#         'updatedAt': '2021-08-09T12:54:32Z',
#         'changedFiles': 1,
#         'additions': 3,
#         'deletions': 1,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'cncf/tag-contributor-strategy'},
#         'createdAt': '2021-06-14T19:30:15Z',
#         'updatedAt': '2021-06-25T16:34:23Z',
#         'changedFiles': 1,
#         'additions': 5,
#         'deletions': 5,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/k8s.io'},
#         'createdAt': '2021-06-07T20:09:25Z',
#         'updatedAt': '2021-06-07T20:16:58Z',
#         'changedFiles': 1,
#         'additions': 2,
#         'deletions': 1,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'cncf/tag-contributor-strategy'},
#         'createdAt': '2021-05-28T18:54:12Z',
#         'updatedAt': '2021-06-25T16:34:24Z',
#         'changedFiles': 1,
#         'additions': 1,
#         'deletions': 1,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'cncf/tag-contributor-strategy'},
#         'createdAt': '2021-05-19T00:30:45Z',
#         'updatedAt': '2021-06-25T16:34:25Z',
#         'changedFiles': 1,
#         'additions': 7,
#         'deletions': 2,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'cncf/toc'},
#         'createdAt': '2021-05-19T00:20:59Z',
#         'updatedAt': '2021-07-13T00:12:31Z',
#         'changedFiles': 1,
#         'additions': 1,
#         'deletions': 2,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'knative/community'},
#         'createdAt': '2021-05-18T23:34:53Z',
#         'updatedAt': '2021-05-24T18:35:52Z',
#         'changedFiles': 1,
#         'additions': 19,
#         'deletions': 0,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'knative/community'},
#         'createdAt': '2021-04-28T22:41:49Z',
#         'updatedAt': '2021-04-29T13:38:55Z',
#         'changedFiles': 1,
#         'additions': 2,
#         'deletions': 0,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'elekto-io/elekto'},
#         'createdAt': '2021-04-24T00:06:01Z',
#         'updatedAt': '2021-04-24T00:14:11Z',
#         'changedFiles': 2,
#         'additions': 12,
#         'deletions': 2,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'knative/community'},
#         'createdAt': '2021-04-23T18:24:13Z',
#         'updatedAt': '2021-04-23T18:27:39Z',
#         'changedFiles': 3,
#         'additions': 2,
#         'deletions': 4,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes-sigs/lwkd'},
#         'createdAt': '2021-04-22T23:09:50Z',
#         'updatedAt': '2021-04-27T06:06:22Z',
#         'changedFiles': 5,
#         'additions': 84,
#         'deletions': 23,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'knative/community'},
#         'createdAt': '2021-04-22T23:02:01Z',
#         'updatedAt': '2021-04-23T17:12:39Z',
#         'changedFiles': 2,
#         'additions': 2,
#         'deletions': 4,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'knative/community'},
#         'createdAt': '2021-04-13T00:06:50Z',
#         'updatedAt': '2021-04-13T13:56:01Z',
#         'changedFiles': 3,
#         'additions': 150,
#         'deletions': 111,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'knative/community'},
#         'createdAt': '2021-04-12T18:11:25Z',
#         'updatedAt': '2021-04-12T18:40:43Z',
#         'changedFiles': 1,
#         'additions': 104,
#         'deletions': 1,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'knative/community'},
#         'createdAt': '2021-04-12T18:05:16Z',
#         'updatedAt': '2021-04-12T18:06:36Z',
#         'changedFiles': 5,
#         'additions': 265,
#         'deletions': 5,
#         'state': 'CLOSED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'knative/community'},
#         'createdAt': '2021-04-09T19:38:26Z',
#         'updatedAt': '2021-04-12T16:46:43Z',
#         'changedFiles': 5,
#         'additions': 162,
#         'deletions': 5,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'knative/community'},
#         'createdAt': '2021-04-09T18:58:45Z',
#         'updatedAt': '2021-04-09T19:19:00Z',
#         'changedFiles': 5,
#         'additions': 278,
#         'deletions': 0,
#         'state': 'CLOSED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'knative/community'},
#         'createdAt': '2021-04-07T23:15:19Z',
#         'updatedAt': '2021-04-07T23:16:10Z',
#         'changedFiles': 5,
#         'additions': 278,
#         'deletions': 0,
#         'state': 'CLOSED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'cncf/project-template'},
#         'createdAt': '2021-03-29T21:26:59Z',
#         'updatedAt': '2021-04-29T17:34:37Z',
#         'changedFiles': 1,
#         'additions': 226,
#         'deletions': 0,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'konveyor/community'},
#         'createdAt': '2021-03-29T17:59:15Z',
#         'updatedAt': '2021-08-06T19:48:33Z',
#         'changedFiles': 1,
#         'additions': 172,
#         'deletions': 0,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'containers/podman'},
#         'createdAt': '2021-03-19T20:27:23Z',
#         'updatedAt': '2021-04-26T13:57:28Z',
#         'changedFiles': 2,
#         'additions': 11,
#         'deletions': 2,
#         'state': 'CLOSED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/sig-release'},
#         'createdAt': '2021-03-17T23:38:44Z',
#         'updatedAt': '2021-03-18T09:41:28Z',
#         'changedFiles': 1,
#         'additions': 0,
#         'deletions': 6,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'kubernetes/community'},
#         'createdAt': '2021-02-24T00:20:46Z',
#         'updatedAt': '2021-02-25T14:29:30Z',
#         'changedFiles': 1,
#         'additions': 6,
#         'deletions': 3,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'cncf/project-template'},
#         'createdAt': '2021-01-15T23:09:12Z',
#         'updatedAt': '2021-03-18T17:28:11Z',
#         'changedFiles': 2,
#         'additions': 174,
#         'deletions': 0,
#         'state': 'MERGED'}},
#       {'pullRequest': {'repository': {'nameWithOwner': 'containers/ContainerPlumbing'},
#         'createdAt': '2021-01-06T00:48:50Z',
#         'updatedAt': '2021-01-06T00:49:33Z',
#         'changedFiles': 1,
#         'additions': 17,
#         'deletions': 27,
#         'state': 'MERGED'}}]},
#     'commitContributionsByRepository': [{'repository': {'nameWithOwner': 'kubernetes-sigs/lwkd'},
#       'contributions': {'totalCount': 71,
#        'nodes': [{'occurredAt': '2021-12-13T08:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-12-06T08:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-11-30T08:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-11-22T08:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-11-16T08:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-11-15T08:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-11-08T08:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-11-01T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-10-25T07:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-10-19T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-10-04T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-09-28T07:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-09-21T07:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-09-20T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-08-30T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-08-23T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-08-17T07:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-08-16T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-08-09T07:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-08-02T07:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-07-30T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-07-26T07:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-07-19T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-07-12T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-07-07T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-07-06T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-06-28T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-06-21T07:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-06-14T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-06-08T07:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-06-07T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-06-01T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-05-25T07:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-05-17T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-05-10T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-05-03T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-04-26T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-04-22T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-04-20T07:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-04-19T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-04-05T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-03-29T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-03-22T07:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-03-17T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-03-08T08:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-03-01T08:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-02-22T08:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-02-08T08:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-02-02T08:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-01-25T08:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-01-18T08:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-01-12T08:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-01-04T08:00:00Z', 'commitCount': 2}]}},
#      {'repository': {'nameWithOwner': 'elekto-io/elekto'},
#       'contributions': {'totalCount': 33,
#        'nodes': [{'occurredAt': '2021-10-21T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-10-19T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-10-18T07:00:00Z', 'commitCount': 4},
#         {'occurredAt': '2021-10-07T07:00:00Z', 'commitCount': 3},
#         {'occurredAt': '2021-10-06T07:00:00Z', 'commitCount': 4},
#         {'occurredAt': '2021-10-01T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-09-24T07:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-09-23T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-09-01T07:00:00Z', 'commitCount': 3},
#         {'occurredAt': '2021-08-29T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-08-27T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-08-24T07:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-08-23T07:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-08-20T07:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-07-30T07:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-07-28T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-07-09T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-04-23T07:00:00Z', 'commitCount': 1}]}},
#      {'repository': {'nameWithOwner': 'containers/ContainerPlumbing'},
#       'contributions': {'totalCount': 28,
#        'nodes': [{'occurredAt': '2021-04-30T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-04-08T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-03-08T08:00:00Z', 'commitCount': 6},
#         {'occurredAt': '2021-03-02T08:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-03-01T08:00:00Z', 'commitCount': 4},
#         {'occurredAt': '2021-02-19T08:00:00Z', 'commitCount': 3},
#         {'occurredAt': '2021-02-02T08:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-01-27T08:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-01-26T08:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-01-25T08:00:00Z', 'commitCount': 4},
#         {'occurredAt': '2021-01-22T08:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-01-05T08:00:00Z', 'commitCount': 2}]}},
#      {'repository': {'nameWithOwner': 'elekto-io/docs'},
#       'contributions': {'totalCount': 24,
#        'nodes': [{'occurredAt': '2021-10-21T07:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-10-20T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-10-19T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-10-18T07:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-10-04T07:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-08-06T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-08-05T07:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-08-03T07:00:00Z', 'commitCount': 6},
#         {'occurredAt': '2021-07-20T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-01-12T08:00:00Z', 'commitCount': 6}]}},
#      {'repository': {'nameWithOwner': 'kubernetes/community'},
#       'contributions': {'totalCount': 23,
#        'nodes': [{'occurredAt': '2021-12-17T08:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-12-09T08:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-12-02T08:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-11-08T08:00:00Z', 'commitCount': 3},
#         {'occurredAt': '2021-11-05T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-10-16T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-10-15T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-10-08T07:00:00Z', 'commitCount': 3},
#         {'occurredAt': '2021-10-05T07:00:00Z', 'commitCount': 5},
#         {'occurredAt': '2021-10-01T07:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-09-30T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-09-26T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-08-30T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-02-23T08:00:00Z', 'commitCount': 1}]}},
#      {'repository': {'nameWithOwner': 'cncf/tag-contributor-strategy'},
#       'contributions': {'totalCount': 22,
#        'nodes': [{'occurredAt': '2021-12-13T08:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-12-10T08:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-11-11T08:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-08-24T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-08-17T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-08-12T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-08-06T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-07-16T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-06-14T07:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-06-01T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-05-28T07:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-05-20T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-05-18T07:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-04-29T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-04-28T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-04-13T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-02-25T08:00:00Z', 'commitCount': 3}]}},
#      {'repository': {'nameWithOwner': 'knative/community'},
#       'contributions': {'totalCount': 13,
#        'nodes': [{'occurredAt': '2021-12-02T08:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-11-29T08:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-11-16T08:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-11-08T08:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-11-04T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-10-20T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-05-20T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-04-29T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-04-23T07:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-04-13T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-04-12T07:00:00Z', 'commitCount': 2}]}},
#      {'repository': {'nameWithOwner': 'kubernetes/k8s.io'},
#       'contributions': {'totalCount': 11,
#        'nodes': [{'occurredAt': '2021-10-20T07:00:00Z', 'commitCount': 3},
#         {'occurredAt': '2021-10-19T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-10-07T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-09-24T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-09-23T07:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-09-21T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-08-03T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-06-07T07:00:00Z', 'commitCount': 1}]}},
#      {'repository': {'nameWithOwner': 'elekto-io/elekto.meta.test'},
#       'contributions': {'totalCount': 11,
#        'nodes': [{'occurredAt': '2021-10-05T07:00:00Z', 'commitCount': 4},
#         {'occurredAt': '2021-10-01T07:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-08-18T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-01-13T08:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-01-08T08:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-01-07T08:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-01-06T08:00:00Z', 'commitCount': 1}]}},
#      {'repository': {'nameWithOwner': 'carolynvs/contributor-strategy-talks'},
#       'contributions': {'totalCount': 7,
#        'nodes': [{'occurredAt': '2021-03-30T07:00:00Z', 'commitCount': 5},
#         {'occurredAt': '2021-03-26T07:00:00Z', 'commitCount': 2}]}},
#      {'repository': {'nameWithOwner': 'CommunityCentral/communitycentral.github.io'},
#       'contributions': {'totalCount': 6,
#        'nodes': [{'occurredAt': '2021-07-02T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-06-25T07:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-03-02T08:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-02-18T08:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-02-10T08:00:00Z', 'commitCount': 1}]}},
#      {'repository': {'nameWithOwner': 'kubernetes/contributor-site'},
#       'contributions': {'totalCount': 3,
#        'nodes': [{'occurredAt': '2021-12-13T08:00:00Z', 'commitCount': 2},
#         {'occurredAt': '2021-12-06T08:00:00Z', 'commitCount': 1}]}},
#      {'repository': {'nameWithOwner': 'cncf/project-template'},
#       'contributions': {'totalCount': 3,
#        'nodes': [{'occurredAt': '2021-06-25T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-05-19T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-01-15T08:00:00Z', 'commitCount': 1}]}},
#      {'repository': {'nameWithOwner': 'cncf/toc'},
#       'contributions': {'totalCount': 2,
#        'nodes': [{'occurredAt': '2021-12-07T08:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-05-18T07:00:00Z', 'commitCount': 1}]}},
#      {'repository': {'nameWithOwner': 'etcd-io/website'},
#       'contributions': {'totalCount': 2,
#        'nodes': [{'occurredAt': '2021-11-19T08:00:00Z', 'commitCount': 2}]}},
#      {'repository': {'nameWithOwner': 'jberkus/jberkus.github.io'},
#       'contributions': {'totalCount': 2,
#        'nodes': [{'occurredAt': '2021-11-04T07:00:00Z', 'commitCount': 2}]}},
#      {'repository': {'nameWithOwner': 'kubevirt/community'},
#       'contributions': {'totalCount': 2,
#        'nodes': [{'occurredAt': '2021-09-02T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-08-09T07:00:00Z', 'commitCount': 1}]}},
#      {'repository': {'nameWithOwner': 'kubevirt/kubevirt.github.io'},
#       'contributions': {'totalCount': 2,
#        'nodes': [{'occurredAt': '2021-08-18T07:00:00Z', 'commitCount': 2}]}},
#      {'repository': {'nameWithOwner': 'konveyor/community'},
#       'contributions': {'totalCount': 2,
#        'nodes': [{'occurredAt': '2021-07-28T07:00:00Z', 'commitCount': 1},
#         {'occurredAt': '2021-03-29T07:00:00Z', 'commitCount': 1}]}},
#      {'repository': {'nameWithOwner': 'knative/docs'},
#       'contributions': {'totalCount': 2,
#        'nodes': [{'occurredAt': '2021-04-13T07:00:00Z', 'commitCount': 2}]}},
#      {'repository': {'nameWithOwner': 'kubernetes/website'},
#       'contributions': {'totalCount': 1,
#        'nodes': [{'occurredAt': '2021-11-09T08:00:00Z', 'commitCount': 1}]}},
#      {'repository': {'nameWithOwner': 'okd-virtualization/okd-virtualization.github.io'},
#       'contributions': {'totalCount': 1,
#        'nodes': [{'occurredAt': '2021-10-25T07:00:00Z', 'commitCount': 1}]}},
#      {'repository': {'nameWithOwner': 'kubernetes/steering'},
#       'contributions': {'totalCount': 1,
#        'nodes': [{'occurredAt': '2021-09-29T07:00:00Z', 'commitCount': 1}]}},
#      {'repository': {'nameWithOwner': 'kubevirt/kubevirt'},
#       'contributions': {'totalCount': 1,
#        'nodes': [{'occurredAt': '2021-08-17T07:00:00Z', 'commitCount': 1}]}},
#      {'repository': {'nameWithOwner': 'apache/superset'},
#       'contributions': {'totalCount': 1,
#        'nodes': [{'occurredAt': '2021-08-06T07:00:00Z',
#          'commitCount': 1}]}}]}}}}
